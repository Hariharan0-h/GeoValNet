# %%
import sys
sys.path.append("..")

from src.features.combined_pipeline import load_combined_features

# %%
X_combined, y = load_combined_features(
    "../data/raw/kc_house_data.csv",
    "../data/processed/embeddings_k10.npy"
)

# %%
print("Combined Feature Shape:", X_combined.shape)

print("Target Shape:", y.shape)
# Out:
# Combined Feature Shape: (21613, 40)
# Target Shape: (21613,)

# %%
print(X_combined[:2])
# Out:
# [[ 3.00000000e+00  1.00000000e+00  1.18000000e+03  5.65000000e+03
#    1.00000000e+00  7.00000000e+00  4.75112000e+01 -1.22257000e+02
#    4.08273011e-01 -1.45232648e-01  3.04229418e-03  8.72933388e-01
#    7.60641932e-01 -1.46491259e-01 -4.63674068e-01 -9.59545672e-01
#    7.11012661e-01  2.58003414e-01  1.90194342e-02  5.53996116e-03
#    3.28332275e-01 -9.43236873e-02 -7.51277030e-01 -2.70347714e-01
#    1.05409026e-02 -3.87004167e-02  4.94129688e-01 -1.85497001e-01
#    2.38201410e-01  1.90812409e-01 -1.04443520e-01  7.78435320e-02
#   -7.54563987e-01 -2.93862019e-02 -7.40027487e-01  8.47586751e-01
#   -2.84147352e-01  6.33646429e-01 -1.75127713e-03  8.40437412e-01]
#  [ 3.00000000e+00  2.25000000e+00  2.57000000e+03  7.24200000e+03
#    2.00000000e+00  7.00000000e+00  4.77210000e+01 -1.22319000e+02
#    1.12035906e+00 -9.70189869e-01  7.30331898e-01  7.38766491e-02
#   -2.48442620e-01 -1.26135159e+00 -1.74106613e-01  1.04860455e-01
# ...
